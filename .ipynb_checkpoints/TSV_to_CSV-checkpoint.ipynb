# %%
# IMPORTO LIBRERÍA RE PARA PODER IDENTIFICAR LAS TABULACIONES Y REEMPLAZARLAS POR COMAS
import re

# IMPORTO PANDAS PARA TRABAJAR CON LOS DATOS EN FORMATO DATAFRAME
import pandas as pd

# %% [markdown]
# Primero intentamos leer el archivo separado tabularmente por medio de pandas indicando el separador

# %%
df = pd.read_table("datos_data_engineer.tsv", sep="\t")

# %%
df
# Out:
#        i  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4
# 0    NaN         NaN         NaN         NaN         NaN
# 1    NaN         NaN         NaN         NaN         NaN
# 2    NaN         NaN         NaN         NaN         NaN
# 3    NaN         NaN         NaN         NaN         NaN
# 4    NaN         NaN         NaN         NaN         NaN
# ...   ..         ...         ...         ...         ...
# 1002 NaN         NaN         NaN         NaN         NaN
# 1003 NaN         NaN         NaN         NaN         NaN
# 1004 NaN         NaN         NaN         NaN         NaN
# 1005 NaN         NaN         NaN         NaN         NaN
# 1006 NaN         NaN         NaN         NaN         NaN
#
# [1007 rows x 5 columns]

# %% [markdown]
# Vemos que no trae datos y supongo que tiene que ver con el encoding mencionado en el pdf. Por eso probamos nuevamente la lectura pero especificando el encoding

# %%
df2 = pd.read_table("datos_data_engineer.tsv", sep="\t", encoding="UTF-16LE")

# %%
df2
# Out:
#         id first_name   last_name account_number  \
# 0        1    Addison       Marks         196296
# 1        2     Dakota       Garza         409025
# 2        3      Basia       Wolfe         637720
# 3        4   Germaine    Campbell         826846
# 4        5     Lenore  Pennington         345284
# ...    ...        ...         ...            ...
# 1002   996   Kirestin       Potts         653131
# 1003   997    Kristen       Stout         628705
# 1004   998     Daniel      Snider         535804
# 1005   999     Simone      Mcleod         407847
# 1006  1000   Hermione     Morales         478506
#
#                                         email
# 0                        ornare.lectus@et.edu
# 1              scelerisque@Praesentluctus.edu
# 2                Aliquam@nullaIntegerurna.com
# 3                 id.magna@viverraMaecenas.ca
# 4                         aliquam@Integer.edu
# ...                                       ...
# 1002                        in@accumsan.co.uk
# 1003               tempus@Loremipsumdolor.edu
# 1004  porttitor.tellus.non@maurisMorbinon.com
# 1005          et.risus@consectetuereuismod.ca
# 1006                       eu.nulla@Donec.com
#
# [1007 rows x 5 columns]

# %% [markdown]
# Efectivamente ese era el inconveniente con la lectura, a partir de acá solo quedaría convertir el dataframe a formato csv con un encoding "UTF-8"

# %%
df2.to_csv("datos_data_engineer.csv", sep="|", encoding="UTF-8", index=False)

# %% [markdown]
# Intentamos leer el archivo CSV recién generado pero con el encoding viejo para verificar que no haya mantenido el mismo encoding

# %%
df_encoding_incorrecto = pd.read_csv("datos_data_engineer.csv", encoding="UTF-16LE")

# %%
df_encoding_incorrecto
# Out:
# Empty DataFrame
# Columns: [摩昬物瑳湟浡ⱥ慬瑳湟浡ⱥ捡潣湵彴畮扭牥攬慭汩਍ⰱ摁楤潳Ɱ慍歲ⱳ㤱㈶㘹漬湲牡⹥敬瑣獵敀⹴摥൵㈊䐬歡瑯ⱡ慇穲ⱡ〴〹㔲猬散敬楲煳敵偀慲獥湥汴捵畴⹳摥൵㌊䈬獡慩圬汯敦㘬㜳㈷ⰰ汁煩慵䁭畮汬䥡瑮来牥牵慮挮浯਍ⰴ敇浲楡敮䌬浡扰汥ⱬ㈸㠶㘴椬⹤慭湧䁡楶敶牲䵡敡散慮⹳慣਍ⰵ敌潮敲倬湥楮杮潴Ɱ㐳㈵㐸愬楬畱浡䥀瑮来牥攮畤਍ⰶ瑓捡ⱹ慓瑮獯㔬㈱㔷ⰹ慶楲獵摀捩畴浭条慮攮畤਍ⰷ慊正䠬湡潣正㘬㐴㠶ⰸ慭湧⹡敳⹤畤䁩瑡楮楳挮浯਍ⰸ潄慬Ɱ潃潬Ɱ㘹ㄹ㔷瘬汥所慬摮瑩挮浯਍ⰹ楍ⱡ潊湨瑳湯㜬㤸㐴ⰸ畡瑣牯渮湯昮略楧瑡汀捥畴⹳慣਍〱䴬污捡楨娬浩敭浲湡㈬㜱㔲ⰰ牥瑡匮摥渮湵䁣畡瑣牯漮杲਍ㄱ䄬汬湥倬畡ⱬ㐶㠴ㄴ儬極煳敵瀮牯瑴瑩牯攮潲䁳数敤牐敡敳瑮挮ൡㄊⰲ慆汬湯䐬湵Ɱ㔴㘳㈸瀬獯敵敲瘮汵異慴整䑀湯捥来獥慴䅳楬畱浡漮杲਍㌱䐬湯慮匬慷獮湯㜬㜲㈱ⰴ潤潬䁲瑥挮ൡㄊⰴ慄瑮ⱥ慃摬敷汬㜬〸㌱ⰳ桐獡汥畬⹳潤潬⹲汥瑩癀癩牥慲慍捥湥獡慩畣楬⹳潣൭ㄊⰵ慐汵䜬慲慨Ɑ㔱㔳㘹愬捵潴⹲楶慴⹥污煩敵䁴慶楲獵挮⹯歵਍㘱䌬牨獩整Ɱ汃癥汥湡Ɽ㠹㤰㌱䄬湥慥⹮慭獳⹡湉整敧䁲楮楳敁敮湡渮瑥਍㜱䈬癥獩䠬瑡楦汥Ɽ㈴〰㐶琬浥潰⹲潬敲⹭来瑥晀捡汩獩獩来瑥灩畳⹭慣਍㠱䬬牥業ⱴ慈敬㘬〹㌲ⰷ牯楣挮湯敳瑣瑥敵䁲湩攮畤਍㤱䤬慭楮䴬杣睯湡㤬㘷㈷ⰲ汰捡牥瑡愮杵敵匮摥桀湥牤牥瑩⹡敮൴㈊ⰰ潈汬敥䜬慲ⱹ〷㠵㔷甬湲⹡瑕琮湩楣畤瑮偀潲湩挮浯਍ㄲ䄬湩汳祥䴬祥牥㐬㌳㘱ⰱ牯楣牀獩獵畱獩渮瑥਍㈲䨬獯灥ⱨ效瑡ⱨ㌲㈰㘰測獩䁩数汬湥整煳敵整汬獵敳⹭慣਍㌲听潨慭ⱳ楒档牡獤湯ㄬ㠱㌸ⰹ牐敡敳瑮捀湯畧䥥獮散敬楲煳敵漮杲਍㐲儬極据ⱹ畂正敮Ⱳ㜶〶㐳瘬汥瑩湀獩敬敬敭瑮浵挮⹯歵਍㔲䰬敥嘬湡散㠬㐷㈰ⰴ潬敲䁭潮畮浭畹瑬楲楣獥牯慮敲挮⹯歵਍㘲丬瑡慨楮汥刬極ⱺ㈳ㄷ㘶洬条慮匮摥攮䁵牡畣潍扲獩瑩挮浯਍㜲䬬浩敢汲祥倬牡獫㌬㤱㜳ⰷ敶瑳扩汵浵氮牯浥献瑩敀敵極浳摯攮畤਍㠲䤬潶祲䐬睯獮ㄬ㌳㜶ⰷ敳䁭敳⹤慣਍㤲䄬敤慮䠬扯獢Ⱜ਍潂汳祥㘬㘵㠱ⰴⰬ਍愬⹣灩畳⹭桐獡汥畬䁳瑵渮瑥Ⱜബ㌊ⰰ慌牵ⱡ楒敶慲㈬〷㘴ⰴ慮捳瑥牵爮摩捩汵獵洮獵䑀湯捥楮桢湥浩漮杲਍ㄳ䌬楬瑮湯嘬湩散瑮㘬㜷〸ⰲ摡灩獩楣杮氮捡獵售䁴瑡楬敢潲攮畤਍㈳愬敲桴ⱡ潔牲獥㈬㠷㈳ⰴ捳汥牥獩畱⹥敮畱⹥敳䁤潣獮煥慵摴汯牯挮ൡ㌊ⰳ畋浡ⱥ牂捵ⱥ㤲㔵㔳洬瑥獵桀湥牤牥瑩敮畱䥥⹮摥൵㌊ⰴ晉潥慭䬬楮桧ⱴ㐹ㄶ㠰猬浥獀条瑩楴⹳牯൧㌊ⰵ潊摲湥䐬摯潳⁮㘬㔰㤲ⰶ畎汬⹡污煩敵⹴牐楯䁮楶慴獥摯污獥瑡挮ൡ㌊ⰶ潈浬獥䜬潯睤湩㘬㌳㌴ⰰ瑥甮瑬楲散⹳潰畳牥䁥瑅慩⹭潣൭㌊ⰷ牁慩慮䐬汩潬Ɱ㘲㠹㠴甬汬浡潣灲牥浀条慮漮杲਍㠳䨬汵慩Ɱ牋浡牥㠬㔱㈹ⰹ敓䁤摡灩獩楣杮潬潢瑲獩楲畳⹳潣甮൫㌊ⰹ楖瑣牯䬬畡浦湡㘬㠸㤰ⰳ慍捥湥獡洮䁩略敳⹭牯൧㐊ⰰ桓敡敬杩ⱨ潐数㘬㜸ㄸⰲ潄敮⹣潰瑲楴潴䁲敦楬⹳牯൧㐊ⰱ潈数䴬瑡楨ⱳ㤴ㄳ㈶瀬湥瑡扩獵敀楬⹴慣਍㈴䈬敲摮湡听汹牥㌬㠴〴ⰷ数汬湥整煳敵琮汥畬⹳敳䁭楶慴⹥潣甮൫㐊ⰳ敊牲ⱹ敭牲瑩ⱴ㐴㐰㜰氬牯浥献瑩愮敭䁴略潤潬⹲潣甮൫㐊ⰴ牂瑩慴祮匬整桰湥ⱳㄴ㐲㔰丬湵⹣敳䁤牦湩楧汬敡極浳摯湥浩挮浯਍㔴椬湧捡慩‬潤湷ⱳ〵〵㠳嘬癩浡獵攮極浳摯甮湲䁡摩楬敢潲挮⹯歵਍㘴氬汩楬桴洬摣湡敩ⱬ〲㠴ㄶ甬瑬楲楣獥氮杩汵䁡牧癡摩⹡潣甮൫㐊ⰷ牂摯ⱹ敇牯敧㌬ㄹ㤲ⰳ潴瑲牯敀⹴潣൭㐊ⰸ慄楮汥敬䴬捣畬敲㌬㘹㈲ⰹ汁煩慵⹭楮汳畀⹴慣਍㤴䄬敬楸ⱳ畓汬癩湡㐬㌴㔰ⰱ潭扲⹩牴獩楴畱⹥敳敮瑣獵獀条瑩楴汳扯牯楴浳畡楲⹳潣൭㔊ⰰ慎摹ⱡ片来牯ⱹ㠶〵㘹匬摥渮汵慬愮瑮䁥牡畣畃慲楢畴畲⹴慣਍ㄵ丬捩汯ⱥ楒敬ⱹ㜸㠷㌸氬扯牯楴䁳潭敬瑳敩牡畣敓⹤潣൭㔊ⰲ態潴倬潯敬ㄬ㈷ㄵⰰ潬敲䁭當灬瑵瑡湥獩獩浥漮杲਍㌵䄬業祴䈬污ⱬ㈳㐳㘵䤬瑮来牥敀敧瑳獡汁煩慵湭捥挮ൡ㔊ⰴ祃瑮楨ⱡ潓楬ⱳ㤹㜳㈱氬捡獵䴮畡楲⹳潮䁮牥瑡潶畬灴瑡挮浯਍㔵匬灯汯湩ⱥ潃灭潴Ɱ㠴ㄴ㠶匬獵数摮獩敳琮楲瑳煩敵渮煥敵癀獥楴畢畬⹭牯൧㔊ⰶ畊楬瑥䄬散敶潤ㄬ㤸㔷ⰰ敶楬⹴来瑥楀獰浵挮浯਍㜵䠬歡敥Ɑ潌数ⱺ㤳㐰㠱搬極渮捥甮湲䁡敬瑣獵渮瑥਍㠵䜬潥晦敲ⱹ慂汲睯ㄬ㠲㜳ⰹ楳⹴浡瑥偀潲湩攮畤਍㤵刬来湩ⱡ湅汧湡Ɽ㌸㜳㤱挬湯敳畱瑡渮捥楀⹤牯൧㘊ⰰ汁摡楤Ɱ潍牲睯㔬ㄵ㜹ⰳ畡畧⹥摩偀慨敳汬獵牯慮敲畆捳⹥慣਍ㄶ䠬摥ⱹ潈慧Ɱ〴㈰㘶洬条慮敀極浳摯漮杲਍㈶䈬牵潴Ɱ汇獡ⱳ㐷㈳㜶攬䁵畃慲楢畴⹲潣甮൫㘊ⰳ牂湥慤嘬污湥畺汥ⱡ㤴㌴〲琬牵楰⹳畎汬⹡污煩敵䁴瑡渮瑥਍㐶丬瑡慨楮汥刬橯獡㜬㜰㘹ⰴ慭敬畳摡⹡瑵献浥慀楬畱瑥摯潩瑅慩⹭敮൴㘊ⰵ潈数䠬污ⱥ㘵ㄴ〱搬極献浥数⹲瑥湀汵慬瑡挮⹯歵਍㘶䨬湥ⱡ敔牲ⱹ㌸ㄷ㐷洬牯楢琮楲瑳煩敵献湥捥畴䁳潄敮湣扩⹨潣൭㘊ⰷ敓瑰浥敢Ⱳ潔湷敳摮㘬㘶㈳ⰵ牐楯䁮潄敮⹣慣਍㠶匬敨汬祥䴬捣牯業正††††㌬㘲㔳ⰲ畄獩朮慲楶慤慀瑣汥畬⹳摥൵㘊ⰹ敄敭牴畩ⱳ楎潸Ɱ㘲ㄸ〱搬杩楮獳浩䴮敡散慮⹳牯慮敲獀条瑩楴䑳極杳慲楶慤渮瑥਍〷䠬汩慤䔬楲正潳Ɱ㐶㘰〶猬浥数䁲敮汣潥潍扲⹩牯൧㜊ⰱ態썹Ⲉ潎汥㐬㐶㜹ⰲ敁敮湡洮獡慳䤮瑮来牥慀瑮䵥敡散慮浳⹩潣甮൫㜊ⰲ楋祡摡ⱡ牔癥湩Ɐ㐵ㄱ㜲氬捥畴⹳䁡浡瑥敭畴⹳潣甮൫㜊ⰳ敎敲ⱡ慍煲敵ⱺ㐵㤲〸洬汯獥楴⹥整汬獵䄮湥慥䁮潮橮獵潴挮ൡ㜊ⰴ楗浬ⱡ祈敤㈬㐸ㄴⰶ摩攮楮䁭敳桤湥牤牥瑩挮⹯歵਍㔷嘬敩歬ⱡ慆浲牥㌬㈱㐶ⰱ桐獡汥畬⹳汥瑩楀瑮牥畤⹭敮൴㜊ⰶ慍散ⱹ敒摩ㄬ㌰㈹ⰸ畲牴浵浀条楮摳獩慰瑲牵敩瑮漮杲਍㜷䰬睡敲据ⱥ敐整獲湥㌬㠷㔷ⰷ畮据椮瑮牥畤䁭潄敮⹣潣൭㜊ⰸ敂湲牡Ɽ敍敹Ⱳ㈵㠶㌶搬慩⹭牐楯⹮潤潬䁲污煩敵⹴潣൭㜊ⰹ湉牧摩䠬牡敲汬㤬ㄶ㐳ⰸ敮⹣浩数摲敩䁴敳⹤潣甮൫㠊ⰰ潒慷Ɱ畂档湡湡㌬㠶㜷ⰷ楬敢潲氮捡獵瘮牡畩䁳牯楣瑕漮杲਍ㄸ䐬湯癯湡䜬敲湥ⱥ㘵㔱㤰攬楮⹭潣浭摯⹯敨摮敲楲䁴潣癮污楬楳据牵畳⹳潣൭㠊ⰲ慊敤䈬瑡汴ⱥബ ††㔬ㄳ㤶ⰵ敬瑣獵樮獵潴汀牯浥挮⹯歵Ⱜ਍㌸丬癥摡ⱡ汢捡Ⱬ〵㤴㔶攬楮⹭潣摮浩湥畴䁭⹡敮൴㠊ⰴ敂敶汲ⱹ潂汹ⱥ㈶㜵㤳䌬浵慀灴摥䍥慲⹳敮൴㠊ⰵ祘慬䈬捵汫祥㤬㤲〶ⰳ略獩潭⹤牵慮楀⹤潣甮൫㠊ⰶ楌畮ⱳ潃湮牥㔬㌸ㄶⰱ捡畣獭湡渮煥敵獀瑩浡瑥渮瑥਍㜸䔬楬湡ⱡ湋灡Ɒ㐲㔹ㄱ測煥敵献摥搮捩畴䁭楬畧慬挮⹯歵਍㠸䠬摥敬ⱹ潇摲湯㠬㜵㤵ⰹ潬敲⹭畡瑣牯焮極䁳潬敲敭⹵潣൭㠊ⰹ慈晹ⱡ桃牵档㌬〸㘳ⰵ敦浲湥畴⹭楲畳䁳慍牵獩畱獩畴灲獩挮⹯歵਍〹䨬摵桡䴬祡ㄬ㘲ㄶⰱ牦湩楧汬⹡異畲⹳慭牵獩乀汵慬⹭敮൴㤊ⰱ慈業桳圬牡ⱥ〶㠴㤶攬瑳洮汯楬䁳楮汳慍捥湥獡慭敬畳摡⹡敮൴㤊ⰲ慌瑩ⱨ湋杩瑨㤬㌲㤸ⰶ潰瑲楴潴⹲捳汥牥獩畱⹥敮畱䁥牴獩楴畱灥慨敲牴⹡潣൭㤊ⰳ癁敹䘬慲据Ɐㄲ㈳㌲攬楮⹭慍牵獩焮極䁳敬瑣獵挮ൡ㤊ⰴ慄湷听慲楶ⱳ㌲㌷ㄳ愬捣浵慳⹮潣癮污楬⹳湡整湀湯挮ൡ㤊ⰵ慓慶湮桡䠬汯潣扭㐬ㄷ㜸ⰷ慍牵獩戮慬摮瑩敀楬⹴潣൭㤊ⰶ畊瑳湩ⱡ牂湡档㤬㈷㘱ⰶ潬潢瑲獩焮慵䁭畲牴浵攮畤਍㜹䈬硡整Ⱳ瑓楲正慬摮㠬〱ㄹⰴ潭敬瑳敩愮捲䁵畑獩畱灥牵獵慳楰湥漮杲਍㠹夬獯楨Ɐ效獮湯㤬㘳㈲ⰳ敶楨畣慬獀浥攮畤਍㤹嘬畡桧湡匬慬整Ⱳ㔸㈴〴愬楬畱瑥漮楤⹯瑅慩䁭略汵牴捩獥渮瑥਍〱ⰰ慐牴捩慩䄬獬潴Ɱ㌵㔷㘱琬湩楣畤瑮渮湵䁣敓敤敧汴捡獵渮瑥਍〱ⰱ慈敫浥圬牡Ɽ㜲㠴㠷䤬瑮来牥晀畡楣畢潳捲⹩慣਍〱ⰲ扁慲伬獬湥㈬㜳㠲ⰲ敓䁤潄敮散敬敭瑮浵攮畤਍〱ⰳ慊慮䠬捩浫湡ㄬ㌴㈴ⰵ畣獲獵渮湯攮敧瑳獡獀灡敩⹮敮൴ㄊ㐰䌬楬瑮湯圬獡楨杮潴Ɱ㜱㈹㜴䐬極䁳楮桢挮⹯歵਍〱ⰵ潣慮Ɱ汢捡Ⱬ㈳㜷㈳甬瑬楲楣獥漮湲牡⹥汥瑩晀楲杮汩慬畣獲獵異畲⹳潣൭ㄊ㘰挬污獩慴挬獡楴汬Ɐ㈳㐳㠷樬獵潴晀牥敭瑮浵潣癮污楬⹳摥൵ㄊ㜰娬湥楡慤䴬捡潤慮摬㔬〹ㄸⰳ来獥慴⹳敓⹤桰牡瑥慲汀捡獵挮ൡㄊ㠰䄬瑳慲䴬汩獬㐬㈴㌰ⰹ瑥渮湵䁣畮汬慡瑮楥捡汵獩攮畤਍〱ⰹ湉楤潧丬硩湯㘬㔰㈱ⰷ慬牯敥⹴潰畳牥⹥湥浩偀慲獥湥⹴摥൵ㄊ〱䄬牵牯ⱡ楂桳灯㤬㐹㠶ⰱ来獥慴⹳敨摮敲楲⹴敮畱䁥慭敬畳摡浡污獥慵慤攮畤਍ㄱⰱ慊潣Ɫ敊獮湥㈬〷㤳ⰴ牥瑡瘮汥浀獡慳挮ൡㄊ㈱䬬汹湡䴬牡楴Ɱㄲ㘶㔳挬湯慶汬獩攮瑳瘮瑩敡慀浣瑡楴⹳敮൴ㄊ㌱䬬慥敮䔬杮慬摮㐬㌱㌴ⰷ畤䁩畤⹩摥൵ㄊ㐱䄬數ⱬ畄慲Ɱ㌲㌱㐱昬捡汩獩䁩潄敮⹣潣甮൫ㄊ㔱䰬乙ⱎ䅃呒剅㔬㜶㄰ⰹ業牀獩獵潄敮⹣敮൴ㄊ㘱䜬楲晦湩䌬慨Ɱ㘲㈳㤹䰬牯浥椮獰浵搮汯牯晀汥獩挮⹯歵਍ㄱⰷ慅潴Ɱ敂捡ⱨ㐶㠶㜳‬牦湩楧汬⹡潰瑲楴潴䁲略獩潭⹤慣਍ㄱⰸ潊汥敬刬獵敳汬㤬㈱㠷ⰴ異畲䁳桐獡汥畬汳扩牥浯畡楲⹳敮൴ㄊ㤱夬獡物䈬牵敮瑴㐬㠷㠰ⰷ敬瑣獵䌮浵䙀獵散敦浲湥畴晭牥敭瑮浵渮瑥਍㈱ⰰ慍杧敩䰬瑩汴ⱥ㘷㈳㘹愬䁣数慮楴畢敳⹴潣甮൫ㄊㄲ匬批汩䐬湯癯湡㈬㜰㈴ⰰ畃慲楢畴⹲敶⹬敬瑣獵䥀獮散敬楲煳敵挮⹯歵਍㈱ⰲ慍楤潳Ɱ楒敬ⱹㄸ㌳㤲測湵䁣畱獩慭獳䵡畡楲⹳牯൧ㄊ㌲䌬汯湩䄬汬獩湯㌬㈱㈶ⰶ畮据渮汵慬瘮汵異慴整晀畡楣畢⹳牯൧ㄊ㐲听湡獩慨䨬桯獮潴Ɱ〳㈶〷攬慲⹴敓䁤慨楢慴瑮潭扲瑩楲瑳煩敵挮浯਍㈱ⰵ祌慳摮慲䰬湡ⱥ㐳㌹㘳氬捡獵䴮畡楲䁳敮浣瑥獵挮⹯歵਍㈱ⰶ慍祣䈬汥ⱬ〸㘵㔰攬楮䁭畡畧卥摥潭敬瑳敩挮浯਍㈱ⰷ楖汯瑥䐬湵Ɱ㤶㜱㜶倬潲湩瘮汥渮獩䁬慭牵獩污煩慵敭⹵潣甮൫ㄊ㠲䤬慮匬硥潴Ɱㄲ㌴㘱愬杵敵愮⹣灩畳䁭汵牴捩敩獳浥慭湧⹡慣਍㈱ⰹ牉慭䜬汩楬浡ㄬ㔶㠰ⰳ畴灲獩慀浣瑡楴⹳牯൧ㄊ〳䐬桡楬ⱡ慒汴晩ⱦ㌵㐲㈲琬湩楣畤瑮搮極愮杵敵摀汯牯楳慴敭⹴敮൴ㄊㄳ䴬物慩Ɑ牄歡ⱥ〳ㄹ㤶甬䁴潭敬瑳敩攮畤਍㌱ⰲ潎汭湡慧䰬湩獤祡㠬㈳㈴ⰵ湩楀瑮牥畤⹭摥൵ㄊ㌳听浡步桡䈬敬楶獮ㄬ㠲㈷ⰱ畡畧⹥捡橀獵潴牐敡敳瑮挮ൡㄊ㐳䬬瑡汥湹䜬楲敭ⱳ㌳㔱㠹搬捩畴⹭畣獲獵丮湵䁣潰畳牥捥扵汩慩挮⹯歵਍㌱ⰵ湁Ɱ楄汬湯㌬ㄹ㌴ⰷ慭牵獩匮獵数摮獩敳噀癩浡獵漮杲਍㌱ⰶ敋湮摥ⱹ潐汯ⱥ㠵ㄸ㌷猬散敬楲煳敵渮煥敵献摥灀摥䍥浵潳楣獩漮杲਍㌱ⰷ牏楬䜬敵牲ⱡ㜱㤷ㄹ攬楬䁴灩畳⹭摥൵ㄊ㠳娬略ⱳ潄湷ⱳ㔴ㄹ㐲椬灭牥楤瑥區獵数摮獩敳捡挮ൡㄊ㤳䜬湥癥敩敶䠬扯獢㐬ㄱ〸ⰱ汵慬捭牯数䁲楲畳䵳牯楢挮浯਍㐱ⰰ潃慮Ɱ楍敬ⱳ㔷㐸㈶漬捲⹩潬潢瑲獩敀楬灴汥敬瑮獥畱⹥敮൴ㄊㄴ䰬睡敲据ⱥ楓獭㜬㠲㠹ⰷ整汬獵樮獵潴汀捡獵瑅慩⹭潣甮൫ㄊ㈴刬湡慤汬倬汯慬摲㔬㔵〸ⰲ潰瑲楴潴⹲整汬獵渮湯汀牯浥瑵挮ൡㄊ㌴倬楨楬Ɒ桃湡Ⱨ〹㐳㤱琬湩楣畤瑮慀挮⹯歵਍㐱ⰴ潃湮牯䌬牡Ⱳ㘵㤱㠴攬瑳乀汵慬楤湧獩楳⹭摥൵ㄊ㔴䔬瑡湯圬楲桧ⱴ㜴㔶㜷昬捡汩獩獩渮湯浀汯獥楴灥慨敲牴湡扩⹨潣൭ㄊ㘴听慨摤略 ...
# Index: []

# %% [markdown]
# Podemos ver que los datos no fueron leidos de forma correcta y se debe al encoding. Ahora probamos con UTF-8

# %%
df_encoding_correcto = pd.read_csv("datos_data_engineer.csv", encoding="UTF-8", sep='|')

# %%
df_encoding_correcto
# Out:
#           id first_name   last_name account_number  \
# 0        1.0    Addison       Marks         196296
# 1        2.0     Dakota       Garza         409025
# 2        3.0      Basia       Wolfe         637720
# 3        4.0   Germaine    Campbell         826846
# 4        5.0     Lenore  Pennington         345284
# ...      ...        ...         ...            ...
# 1002   996.0   Kirestin       Potts         653131
# 1003   997.0    Kristen       Stout         628705
# 1004   998.0     Daniel      Snider         535804
# 1005   999.0     Simone      Mcleod         407847
# 1006  1000.0   Hermione     Morales         478506
#
#                                         email
# 0                        ornare.lectus@et.edu
# 1              scelerisque@Praesentluctus.edu
# 2                Aliquam@nullaIntegerurna.com
# 3                 id.magna@viverraMaecenas.ca
# 4                         aliquam@Integer.edu
# ...                                       ...
# 1002                        in@accumsan.co.uk
# 1003               tempus@Loremipsumdolor.edu
# 1004  porttitor.tellus.non@maurisMorbinon.com
# 1005          et.risus@consectetuereuismod.ca
# 1006                       eu.nulla@Donec.com
#
# [1007 rows x 5 columns]

# %% [markdown]
# Primer objetivo logrado, prosigamos con la limpieza. Lo primero que me llama la atención son los IDs y el desface en la numeración hacia el final del DataFrame

# %%
df_encoding_correcto.sort_values(by='id', ascending=True).tail(20)
# Out:
#               id                               first_name  \
# 993          987                                      NaN
# 994          988                                  Giacomo
# 995          989                                     Gage
# 101           99                                  Vaughan
# 996          990                                    Jayme
# 997          991                                   Hunter
# 998          992                                   Mannix
# 999          993                                    Quinn
# 1000         994                                 Patricia
# 1001         995                                  Celeste
# 1002         996                                 Kirestin
# 1003         997                                  Kristen
# 1004         998                                   Daniel
# 1005         999                                   Simone
# 780      Barbara                                   Hurley
# 29        Bosley                                   656184
# 220   Harrington                               Harrington
# 30           NaN                ac.ipsum.Phasellus@ut.net
# 341          NaN  porttitor.interdum.Sed@Loremipsum.co.uk
# 991          NaN                                   157172
#
#                    last_name                     account_number  \
# 993                   Burris                             233269
# 994                    Hardy                             951442
# 995                    Oneal                             708749
# 101                   Slater                             854240
# 996                  Dillard                             139811
# 997                     Leon                             562993
# 998                 Chambers                             492950
# 999                  Marquez                             179211
# 1000                  Franks                             957295
# 1001                   Craig                             369639
# 1002                   Potts                             653131
# 1003                   Stout                             628705
# 1004                  Snider                             535804
# 1005                  Mcleod                             407847
# 780                   691210         enim.Mauris.quis@magna.net
# 29                       NaN                                NaN
# 220                   325378  neque.Nullam.ut@laoreetlectus.edu
# 30                       NaN                                NaN
# 341                      NaN                                NaN
# 991   enim@disparturient.edu                                NaN
#
#                                         email
# 993                           Sed.et@Proin.ca
# 994                        justo.nec@augue.ca
# 995                               a@velit.edu
# 101         aliquet.odio.Etiam@euultrices.net
# 996                            eu@egestas.edu
# 997                       elit.pede@euarcu.ca
# 998    sit.amet.nulla@DuisgravidaPraesent.org
# 999                  ultrices.Duis@sociis.com
# 1000                           enim@ipsum.edu
# 1001                     magnis@adipiscing.ca
# 1002                        in@accumsan.co.uk
# 1003               tempus@Loremipsumdolor.edu
# 1004  porttitor.tellus.non@maurisMorbinon.com
# 1005          et.risus@consectetuereuismod.ca
# 780                                       NaN
# 29                                        NaN
# 220                                       NaN
# 30                                        NaN
# 341                                       NaN
# 991                                       NaN

# %% [markdown]
# Habiendo visto estos casos raros, hice una verificación abriendo el archivo .tsv original en excel, en dónde pude verificar que el archivo mismo trae estos datos mal cargados y no se deben a una mala lectura del mismo. Teniendo en cuenta que la solución tiene que ser lo más simple posible y no tenemos información sobre por qué sucedió, tampoco sabemos con exactitud si podríamos recuperar estos datos, por lo que tomo la decisión de eliminarlos de la tabla para no cargar datos incorrectos. Vamos a tomar entonces la decisión de conservar aquellas entradas que se encuentren completas. Es probable que esta decisión no sea la primera a tomar en una situación real ya que algunos campos pueden no ser obligatorios y tampoco tenemos el contexto para el cual se utilizan los datos y obviamente eliminar/perder datos no es el objetivo de ningúna base, pero dadas las circunstancias y pensando en que la consistencia y confiabilidad de los datos si son cualidades a buscar, vamos a ir por ese camino.

# %%
df_encoding_correcto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              1004 non-null   object
#  1   first_name      994 non-null    object
#  2   last_name       993 non-null    object
#  3   account_number  997 non-null    object
#  4   email           994 non-null    object
# dtypes: object(5)
# memory usage: 39.5+ KB

# %% [markdown]
# Viendo que los IDs cambiaron su Data Type a 'object' o 'string', voy a volver a hacer esa conversión

# %%
df_encoding_correcto['id'] = pd.to_numeric(df_encoding_correcto['id'], errors='coerce', downcast='integer')

# %%
# ORDENO EL DATAFRAME SEGÚN ID

df_encoding_correcto = df_encoding_correcto.sort_values(by='id')

# %%
# DROPEAMOS AQUELLAS FILAS QUE TENGAN ALGÚN DATO FALTANTE

df_encoding_correcto = df_encoding_correcto.dropna()

# %% [markdown]
# Me gustaría también verificar si hay algún id o account_number duplicado

# %%
# Pregunto si el largo del DataFrame es igual al largo de los unique id

len(df_encoding_correcto['id'].unique()) == len(df_encoding_correcto)
# Out:
# True

# %%
# Pregunto si el largo del DataFrame es igual al largo de los unique account_number

len(df_encoding_correcto['account_number'].unique()) == len(df_encoding_correcto)
# Out:
# False

# %%
df_encoding_correcto['id'] = df_encoding_correcto['id'].astype(int)

# %%
# VIENDO QUE HAY DUPLICADOS EN ACCOUNT_NUMBER LOS BUSCAMOS

df_encoding_correcto[df_encoding_correcto.duplicated(subset='account_number', keep=False)]
# Out:
#       id first_name last_name account_number  \
# 419  415   Courtney   Salinas         114392
# 521  517      Wayne    Wilson         973758
# 910  905      Alice      Dyer         973758
# 939  934       Nora   Leonard         114392
#
#                                       email mail_valido
# 419                            nec@nunc.net      Valido
# 521                   nonummy@iaculis.co.uk      Valido
# 910  vivamus.nibh.dolor@gravidamauris.co.uk      Valido
# 939                  ornare.elit@libero.com      Valido

# %% [markdown]
# En cuanto al campo account_number, no voy a tomar la decisión de eliminar los duplicados porque no sé a ciencia cierta si es un campo que no se puede duplicar. Podría ser el caso que ese account_number vincule a 2 individuos a una misma cuenta, si pensamos en tarjetas de crédito, podrían ser el titular y un adicional.

# %%
# LOS EMAILS NO SON CASE SENSITIVE POR LO QUELOS LLEVAMOS A TODOS A LOWERCASE

df_encoding_correcto['email'] =  df_encoding_correcto['email'].apply(lambda x: x.lower())
df_encoding_correcto['email'] = df_encoding_correcto['email'].str.strip()

# %%
# ESTE REGEX PUEDE NO CAPTAR TODOS LOS EMAILS INVALIDOS

regex = r"(^[a-z0-9_.+-]+@[a-z0-9-]+\.[a-z0-9-.]+$)"


def mail_valido(mail):   
  
    if(re.search(regex,mail)):   
        return 'Valido'  
    else:   
        return 'Invalido'

# %%
df_encoding_correcto['mail_valido'] = df_encoding_correcto['email'].apply(lambda x: mail_valido(x))

# %%
df_encoding_correcto['mail_valido'].value_counts()
# Out:
# Valido    977
# Name: mail_valido, dtype: int64

# %% [markdown]
# Los mails parecen ser correctos bajo el regex implementado (puede no ser 100% efectivo)

# %% [markdown]
# Pasamos entonces a intentar hacer estos pasos repetibles y reutilizables

# %%
def tsv_file(tsv_file_name, csv_file_name):
    
    
    
    df_aux = pd.read_table(tsv_file_name, sep='\t', encoding='UTF-16LE')
    
    df_aux['id'] = pd.to_numeric(df_aux['id'], errors='coerce', downcast='integer')

    df_aux = df_aux.dropna()
    
    df_aux['id'] = df_aux['id'].astype(int)
    
    if len(df_aux['id'].unique()) == len(df_aux):
        
        # Para borrar la menor cantidad de datos nos quedamos con el primero de los duplicados (si hubiera)
        # De todas formas habría que tener más cosas en cuenta como si puedo verificar desde otro lado cual es el correcto
        df_aux = df_aux[df_aux not in df_aux['id'].duplicated(keep='first')]
    
    df_aux = df_aux.sort_values(by='id')
    
    df_final = df_aux.to_csv(csv_file_name, sep='|', encoding='UTF-8', index=False)
    
    return df_final

# %%
df = tsv_file('datos_data_engineer.tsv', 'datos_data_engineer.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-adf5bb5502b6> in <module>
# ----> 1 df = tsv_file('datos_data_engineer.tsv', 'datos_data_engineer.csv')
#
# <ipython-input-122-5010e5a5388a> in tsv_file(tsv_file_name, csv_file_name)
#       5     df_aux = pd.read_table(tsv_file_name, sep='\t', encoding='UTF-16LE')
#       6
# ----> 7     df_aux['id'] = pd.to_numeric(df_aux['id'], errors='coerce', downcast='integer').astype(int)
#       8
#       9     df_aux = df_aux.dropna()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     671             vals1d = values.ravel()
#     672             try:
# --> 673                 values = astype_nansafe(vals1d, dtype, copy=True)
#     674             except (ValueError, TypeError):
#     675                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1066
#    1067         if not np.isfinite(arr).all():
# -> 1068             raise ValueError("Cannot convert non-finite values (NA or inf) to integer")
#    1069
#    1070     elif is_object_dtype(arr):
#
# ValueError: Cannot convert non-finite values (NA or inf) to integer
